# %%
# !pip install tensorflow

# %%
# !pip install sympy
# Out:
# ...
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.3 MB 1.1 MB/s eta 0:00:06
#    ---- ----------------------------------- 0.8/6.3 MB 1.2 MB/s eta 0:00:05
#    ------ --------------------------------- 1.0/6.3 MB 1.3 MB/s eta 0:00:05
#    --------- ------------------------------ 1.6/6.3 MB 1.4 MB/s eta 0:00:04
#    ------------- -------------------------- 2.1/6.3 MB 1.5 MB/s eta 0:00:03
#    -------------- ------------------------- 2.4/6.3 MB 1.6 MB/s eta 0:00:03
#    ------------------ --------------------- 2.9/6.3 MB 1.7 MB/s eta 0:00:03
#    --------------------- ------------------ 3.4/6.3 MB 1.8 MB/s eta 0:00:02
#    ------------------------ --------------- 3.9/6.3 MB 1.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 4.7/6.3 MB 2.0 MB/s eta 0:00:01
# ...

# %%
import sympy

# %%
J, w = sympy.symbols('J,w')

# %%
J = w**3
J
# Out:
# w**3

# %%
J
# Out:
# w**2

# %%
dJ_dW = sympy.diff(J,w)
dJ_dW
# Out:
# 3*w**2

# %%
dJ_dW.subs([(w.2)])
# Out:
#   Cell In[14], line 1
#     dJ_dW.subs([(w.2)])
#                  ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
dJ_dW.subs([(w,2)])
# Out:
# 12
